# %%
import pandas as pd# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score, classification_report
from sklearn.manifold import TSNE

from catboost import CatBoostClassifier
from optuna import create_study
import optuna

from imblearn.over_sampling import SMOTE
from tqdm import tqdm

import seaborn as sns

# %%
# Paths for train and test datasets
TRAIN_SET_PATH = '../data/processed/train_data_selected_engineered.csv'
TEST_SET_PATH = '../data/processed/test_data_selected_engineered.csv'

# Load the dataset
train_data = pd.read_csv(TRAIN_SET_PATH)
test_data = pd.read_csv(TEST_SET_PATH)

# %%
# Split the data into training and validation sets
train_set, validation_set = train_test_split(train_data, test_size=0.2, random_state=42)

# Save the resulting datasets
TRAIN_SPLIT_PATH = '../data/processed/train_split.csv'
VALIDATION_SPLIT_PATH = '../data/processed/validation_split.csv'
train_set.to_csv(TRAIN_SPLIT_PATH, index=False)
validation_set.to_csv(VALIDATION_SPLIT_PATH, index=False)

# Display summary of the training and validation sets
print(f"Training set size: {train_set.shape}")
print(f"Validation set size: {validation_set.shape}")
# Out:
# Training set size: (46916, 16)
# Validation set size: (11729, 16)

# %% [markdown]
# # Model Building

# %%
# Prepare features and target variable
X_train = train_set.drop(columns=['loan_status'])
y_train = train_set['loan_status']
X_validation = validation_set.drop(columns=['loan_status'])
y_validation = validation_set['loan_status']

# %%
# Apply SMOTE to handle class imbalance
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
# Initialize tree-based models to compare
models = {
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100, random_state=42),
    "AdaBoost": AdaBoostClassifier(n_estimators=100, random_state=42),
    "XGBoost": XGBClassifier(n_estimators=100, random_state=42, use_label_encoder=False, eval_metric='logloss')
}

# Train and evaluate each model
for model_name, model in models.items():
    print(f"\nTraining {model_name}...")
    model.fit(X_train_resampled, y_train_resampled)

    # Make predictions on the validation set
    y_pred = model.predict(X_validation)
    y_pred_proba = model.predict_proba(X_validation)[:, 1]

    # Evaluate the model
    roc_auc = roc_auc_score(y_validation, y_pred_proba)
    print(f"{model_name} - ROC AUC Score: {roc_auc}")
    print(classification_report(y_validation, y_pred))
# Out:
# C:\Users\Brett Lill\AppData\Roaming\Python\Python39\site-packages\xgboost\sklearn.py:1395: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# Training Gradient Boosting...
# Gradient Boosting - ROC AUC Score: 0.9250002143350415
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     10087
#            1       0.73      0.73      0.73      1642
#
#     accuracy                           0.92     11729
#    macro avg       0.84      0.84      0.84     11729
# weighted avg       0.92      0.92      0.92     11729
#
#
# Training AdaBoost...
# AdaBoost - ROC AUC Score: 0.9040645712387491
#               precision    recall  f1-score   support
#
#            0       0.96      0.93      0.94     10087
#            1       0.62      0.74      0.67      1642
#
#     accuracy                           0.90     11729
#    macro avg       0.79      0.83      0.81     11729
# weighted avg       0.91      0.90      0.90     11729
#
#
# Training XGBoost...
# XGBoost - ROC AUC Score: 0.9480683401544201
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96     10087
#            1       0.83      0.72      0.77      1642
#
#     accuracy                           0.94     11729
#    macro avg       0.89      0.85      0.87     11729
# weighted avg       0.94      0.94      0.94     11729

# %% [markdown]
# ## Catboost model

# %%
# Function to optimize CatBoost hyperparameters using Optuna
def objective(trial):
    param = {
        'iterations': trial.suggest_int('iterations', 100, 1000),
        'depth': trial.suggest_int('depth', 3, 10),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
        'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
        'random_strength': trial.suggest_uniform('random_strength', 1, 10),
        'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
        'random_state': 42,
        'eval_metric': 'AUC',
        'use_best_model': True,
        'logging_level': 'Silent'
    }
    model = CatBoostClassifier(**param)
    model.fit(X_train_resampled, y_train_resampled, eval_set=[(X_validation, y_validation)], early_stopping_rounds=50, verbose=False)
    y_pred_proba = model.predict_proba(X_validation)[:, 1]
    auc = roc_auc_score(y_validation, y_pred_proba)
    return auc

# %%
# Create Optuna study and optimize hyperparameters with progress bar
study = create_study(direction='maximize')
for _ in tqdm(range(50), desc='Optimizing CatBoost Hyperparameters'):
    study.optimize(objective, n_trials=1, n_jobs=-1)
# Out:
# [I 2024-10-17 15:33:24,894] A new study created in memory with name: no-name-2d03c073-dd33-4c44-8e71-00d7527af8b2
# Optimizing CatBoost Hyperparameters:   0%|                                                                | 0/50 [00:00<?, ?it/s]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:33:49,911] Trial 0 finished with value: 0.9327055590781638 and parameters: {'iterations': 746, 'depth': 6, 'learning_rate': 0.019594395344222023, 'l2_leaf_reg': 0.5345778121627672, 'random_strength': 3.8389921038631303, 'bagging_temperature': 2.1363348365788615}. Best is trial 0 with value: 0.9327055590781638.
# Optimizing CatBoost Hyperparameters:   2%|█                                                       | 1/50 [00:25<20:25, 25.01s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:34:20,765] Trial 1 finished with value: 0.9252943363504865 and parameters: {'iterations': 952, 'depth': 6, 'learning_rate': 0.014285835260107124, 'l2_leaf_reg': 4.8386871286652395, 'random_strength': 8.77469478783781, 'bagging_temperature': 9.944384692498648}. Best is trial 0 with value: 0.9327055590781638.
# Optimizing CatBoost Hyperparameters:   4%|██▏                                                     | 2/50 [00:55<22:45, 28.45s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:34:34,880] Trial 2 finished with value: 0.9435634100258325 and parameters: {'iterations': 555, 'depth': 4, 'learning_rate': 0.08361500804662848, 'l2_leaf_reg': 0.007308032901837722, 'random_strength': 5.049916180721355, 'bagging_temperature': 9.08641557938201}. Best is trial 2 with value: 0.9435634100258325.
# Optimizing CatBoost Hyperparameters:   6%|███▎                                                    | 3/50 [01:09<17:09, 21.90s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:34:55,801] Trial 3 finished with value: 0.9464565104540559 and parameters: {'iterations': 961, 'depth': 3, 'learning_rate': 0.12109777857174259, 'l2_leaf_reg': 0.6991363000372119, 'random_strength': 3.1563894866903066, 'bagging_temperature': 6.795063968296027}. Best is trial 3 with value: 0.9464565104540559.
# Optimizing CatBoost Hyperparameters:   8%|████▍                                                   | 4/50 [01:30<16:29, 21.52s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:35:03,120] Trial 4 finished with value: 0.9399398195504229 and parameters: {'iterations': 243, 'depth': 4, 'learning_rate': 0.12214584696063295, 'l2_leaf_reg': 0.41483788254736265, 'random_strength': 5.682797979812003, 'bagging_temperature': 9.603247467469991}. Best is trial 3 with value: 0.9464565104540559.
# Optimizing CatBoost Hyperparameters:  10%|█████▌                                                  | 5/50 [01:38<12:17, 16.40s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:35:24,649] Trial 5 finished with value: 0.9361296670247772 and parameters: {'iterations': 716, 'depth': 5, 'learning_rate': 0.025906143572297525, 'l2_leaf_reg': 3.261318874054367, 'random_strength': 2.699807459549047, 'bagging_temperature': 7.033479961871382}. Best is trial 3 with value: 0.9464565104540559.
# Optimizing CatBoost Hyperparameters:  12%|██████▋                                                 | 6/50 [01:59<13:18, 18.14s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:35:35,781] Trial 6 finished with value: 0.9459433742518046 and parameters: {'iterations': 424, 'depth': 6, 'learning_rate': 0.17073303072442542, 'l2_leaf_reg': 0.12060809108223543, 'random_strength': 5.002214551056904, 'bagging_temperature': 0.733606461784525}. Best is trial 3 with value: 0.9464565104540559.
# Optimizing CatBoost Hyperparameters:  14%|███████▊                                                | 7/50 [02:10<11:21, 15.85s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:36:05,989] Trial 7 finished with value: 0.9412993678504925 and parameters: {'iterations': 962, 'depth': 6, 'learning_rate': 0.02836187311765259, 'l2_leaf_reg': 0.009689681590183557, 'random_strength': 9.24276235386269, 'bagging_temperature': 9.493528782656425}. Best is trial 3 with value: 0.9464565104540559.
# Optimizing CatBoost Hyperparameters:  16%|████████▉                                               | 8/50 [02:41<14:17, 20.42s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:36:23,609] Trial 8 finished with value: 0.9243189609713397 and parameters: {'iterations': 403, 'depth': 8, 'learning_rate': 0.01612106651184435, 'l2_leaf_reg': 0.044700419426544964, 'random_strength': 4.292825532877421, 'bagging_temperature': 6.689262652134191}. Best is trial 3 with value: 0.9464565104540559.
# Optimizing CatBoost Hyperparameters:  18%|██████████                                              | 9/50 [02:58<13:21, 19.54s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# Training has stopped (degenerate solution on iteration 232, probably too small l2-regularization, try to increase it)
# [I 2024-10-17 15:36:42,897] Trial 9 finished with value: 0.931339490162746 and parameters: {'iterations': 239, 'depth': 10, 'learning_rate': 0.0696992179706407, 'l2_leaf_reg': 0.0012878803030654225, 'random_strength': 5.378783085627322, 'bagging_temperature': 4.352148284807638}. Best is trial 3 with value: 0.9464565104540559.
# Optimizing CatBoost Hyperparameters:  20%|███████████                                            | 10/50 [03:17<12:58, 19.47s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:36:53,929] Trial 10 finished with value: 0.9449186112490034 and parameters: {'iterations': 775, 'depth': 3, 'learning_rate': 0.21300915935266637, 'l2_leaf_reg': 1.0276647359385408e-05, 'random_strength': 1.2514805583509307, 'bagging_temperature': 4.314472910286428}. Best is trial 3 with value: 0.9464565104540559.
# Optimizing CatBoost Hyperparameters:  22%|████████████                                           | 11/50 [03:29<10:58, 16.88s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:37:02,403] Trial 11 finished with value: 0.9405522441965618 and parameters: {'iterations': 474, 'depth': 8, 'learning_rate': 0.24367504863091302, 'l2_leaf_reg': 0.12101751164511085, 'random_strength': 6.828117473886575, 'bagging_temperature': 1.6637458103048712}. Best is trial 3 with value: 0.9464565104540559.
# Optimizing CatBoost Hyperparameters:  24%|█████████████▏                                         | 12/50 [03:37<09:04, 14.33s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:37:16,803] Trial 12 finished with value: 0.9449116680011791 and parameters: {'iterations': 598, 'depth': 3, 'learning_rate': 0.1350496179727594, 'l2_leaf_reg': 0.001241146018003413, 'random_strength': 2.5974519426749785, 'bagging_temperature': 0.674974932230929}. Best is trial 3 with value: 0.9464565104540559.
# Optimizing CatBoost Hyperparameters:  26%|██████████████▎                                        | 13/50 [03:51<08:50, 14.35s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:37:20,849] Trial 13 finished with value: 0.917178464532743 and parameters: {'iterations': 128, 'depth': 8, 'learning_rate': 0.04178320954339647, 'l2_leaf_reg': 0.7691268311602633, 'random_strength': 7.273171733625363, 'bagging_temperature': 6.243521464772262}. Best is trial 3 with value: 0.9464565104540559.
# Optimizing CatBoost Hyperparameters:  28%|███████████████▍                                       | 14/50 [03:55<06:44, 11.24s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:37:37,471] Trial 14 finished with value: 0.9351053266544522 and parameters: {'iterations': 387, 'depth': 10, 'learning_rate': 0.1458140160175392, 'l2_leaf_reg': 0.035435513924150744, 'random_strength': 2.8729763471762895, 'bagging_temperature': 3.016588547830243}. Best is trial 3 with value: 0.9464565104540559.
# Optimizing CatBoost Hyperparameters:  30%|████████████████▌                                      | 15/50 [04:12<07:30, 12.86s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:37:49,565] Trial 15 finished with value: 0.9485344132116361 and parameters: {'iterations': 871, 'depth': 4, 'learning_rate': 0.288208209416868, 'l2_leaf_reg': 7.529979147462386, 'random_strength': 1.3166098010220857, 'bagging_temperature': 0.028744052874497217}. Best is trial 15 with value: 0.9485344132116361.
# Optimizing CatBoost Hyperparameters:  32%|█████████████████▌                                     | 16/50 [04:24<07:09, 12.63s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:38:02,262] Trial 16 finished with value: 0.9478754688050742 and parameters: {'iterations': 870, 'depth': 4, 'learning_rate': 0.2837095913994007, 'l2_leaf_reg': 7.540629000146918, 'random_strength': 1.0013419810524806, 'bagging_temperature': 7.993763607531251}. Best is trial 15 with value: 0.9485344132116361.
# Optimizing CatBoost Hyperparameters:  34%|██████████████████▋                                    | 17/50 [04:37<06:57, 12.65s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:38:15,065] Trial 17 finished with value: 0.948005096223151 and parameters: {'iterations': 837, 'depth': 4, 'learning_rate': 0.29061124549745254, 'l2_leaf_reg': 7.054742563361688, 'random_strength': 1.1466478550453116, 'bagging_temperature': 7.7948017532868}. Best is trial 15 with value: 0.9485344132116361.
# Optimizing CatBoost Hyperparameters:  36%|███████████████████▊                                   | 18/50 [04:50<06:46, 12.70s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:38:22,807] Trial 18 finished with value: 0.9419275204623551 and parameters: {'iterations': 832, 'depth': 5, 'learning_rate': 0.2946816468681853, 'l2_leaf_reg': 5.85011894344477e-05, 'random_strength': 1.847859603276134, 'bagging_temperature': 5.344056854751474}. Best is trial 15 with value: 0.9485344132116361.
# Optimizing CatBoost Hyperparameters:  38%|████████████████████▉                                  | 19/50 [04:57<05:47, 11.21s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:38:43,728] Trial 19 finished with value: 0.9465536555475283 and parameters: {'iterations': 637, 'depth': 5, 'learning_rate': 0.08697056026191952, 'l2_leaf_reg': 2.106346968032212, 'random_strength': 1.9284598990536945, 'bagging_temperature': 8.252184967602119}. Best is trial 15 with value: 0.9485344132116361.
# Optimizing CatBoost Hyperparameters:  40%|██████████████████████                                 | 20/50 [05:18<07:03, 14.12s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:39:11,917] Trial 20 finished with value: 0.9434215262659443 and parameters: {'iterations': 870, 'depth': 7, 'learning_rate': 0.04970497608451341, 'l2_leaf_reg': 0.0015728129865268975, 'random_strength': 3.758723311056886, 'bagging_temperature': 3.220173067280287}. Best is trial 15 with value: 0.9485344132116361.
# Optimizing CatBoost Hyperparameters:  42%|███████████████████████                                | 21/50 [05:47<08:52, 18.35s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:39:26,524] Trial 21 finished with value: 0.9481933488032921 and parameters: {'iterations': 861, 'depth': 4, 'learning_rate': 0.2038213508183961, 'l2_leaf_reg': 9.588606409355991, 'random_strength': 1.0794674545963583, 'bagging_temperature': 7.7989591771393245}. Best is trial 15 with value: 0.9485344132116361.
# Optimizing CatBoost Hyperparameters:  44%|████████████████████████▏                              | 22/50 [06:01<08:02, 17.22s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:39:43,736] Trial 22 finished with value: 0.9486818515697838 and parameters: {'iterations': 671, 'depth': 4, 'learning_rate': 0.19782514827245662, 'l2_leaf_reg': 9.196991570883428, 'random_strength': 1.7431926619220472, 'bagging_temperature': 7.948237709239151}. Best is trial 22 with value: 0.9486818515697838.
# Optimizing CatBoost Hyperparameters:  46%|█████████████████████████▎                             | 23/50 [06:18<07:44, 17.22s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:39:57,357] Trial 23 finished with value: 0.9472069849797625 and parameters: {'iterations': 688, 'depth': 5, 'learning_rate': 0.19810191301873878, 'l2_leaf_reg': 9.644417390200005, 'random_strength': 1.932374599269611, 'bagging_temperature': 8.526378107019976}. Best is trial 22 with value: 0.9486818515697838.
# Optimizing CatBoost Hyperparameters:  48%|██████████████████████████▍                            | 24/50 [06:32<06:59, 16.14s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:40:15,416] Trial 24 finished with value: 0.9466040695643396 and parameters: {'iterations': 788, 'depth': 3, 'learning_rate': 0.17986878158477773, 'l2_leaf_reg': 1.89911612955958, 'random_strength': 2.02210723796045, 'bagging_temperature': 7.544893418355213}. Best is trial 22 with value: 0.9486818515697838.
# Optimizing CatBoost Hyperparameters:  50%|███████████████████████████▌                           | 25/50 [06:50<06:57, 16.72s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:40:34,280] Trial 25 finished with value: 0.9462861291900537 and parameters: {'iterations': 658, 'depth': 4, 'learning_rate': 0.10185975794737022, 'l2_leaf_reg': 1.2472763208045354, 'random_strength': 3.2265437759603373, 'bagging_temperature': 5.58617817962492}. Best is trial 22 with value: 0.9486818515697838.
# Optimizing CatBoost Hyperparameters:  52%|████████████████████████████▌                          | 26/50 [07:09<06:56, 17.36s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# ...
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:45:08,479] Trial 41 finished with value: 0.9471616425526664 and parameters: {'iterations': 924, 'depth': 4, 'learning_rate': 0.2939376733071697, 'l2_leaf_reg': 5.393258852982896, 'random_strength': 1.493483597046819, 'bagging_temperature': 7.567217369524429}. Best is trial 32 with value: 0.9492886914296292.
# Optimizing CatBoost Hyperparameters:  84%|██████████████████████████████████████████████▏        | 42/50 [11:43<02:01, 15.13s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:45:21,995] Trial 42 finished with value: 0.9453247610586919 and parameters: {'iterations': 801, 'depth': 4, 'learning_rate': 0.18081472657283956, 'l2_leaf_reg': 9.098226086097462, 'random_strength': 1.4802850827582497, 'bagging_temperature': 6.709974792400504}. Best is trial 32 with value: 0.9492886914296292.
# Optimizing CatBoost Hyperparameters:  86%|███████████████████████████████████████████████▎       | 43/50 [11:57<01:42, 14.65s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:45:35,562] Trial 43 finished with value: 0.9463685425229251 and parameters: {'iterations': 719, 'depth': 3, 'learning_rate': 0.25213047424663576, 'l2_leaf_reg': 4.75308741614808, 'random_strength': 2.1707719178022895, 'bagging_temperature': 7.036207418146481}. Best is trial 32 with value: 0.9492886914296292.
# Optimizing CatBoost Hyperparameters:  88%|████████████████████████████████████████████████▍      | 44/50 [12:10<01:25, 14.32s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:46:03,542] Trial 44 finished with value: 0.9414518174222873 and parameters: {'iterations': 839, 'depth': 5, 'learning_rate': 0.03142537888445924, 'l2_leaf_reg': 0.765439841906243, 'random_strength': 2.899821620683099, 'bagging_temperature': 8.23272887767966}. Best is trial 32 with value: 0.9492886914296292.
# Optimizing CatBoost Hyperparameters:  90%|█████████████████████████████████████████████████▌     | 45/50 [12:38<01:32, 18.42s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:46:18,634] Trial 45 finished with value: 0.9475610302427347 and parameters: {'iterations': 886, 'depth': 4, 'learning_rate': 0.2000093092199795, 'l2_leaf_reg': 2.153685487165654, 'random_strength': 1.492792686096093, 'bagging_temperature': 9.622736459426585}. Best is trial 32 with value: 0.9492886914296292.
# Optimizing CatBoost Hyperparameters:  92%|██████████████████████████████████████████████████▌    | 46/50 [12:53<01:09, 17.42s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:46:39,827] Trial 46 finished with value: 0.9461907350025545 and parameters: {'iterations': 764, 'depth': 3, 'learning_rate': 0.12700292572527955, 'l2_leaf_reg': 5.015394132025791, 'random_strength': 1.0003466562260135, 'bagging_temperature': 4.74229289791293}. Best is trial 32 with value: 0.9492886914296292.
# Optimizing CatBoost Hyperparameters:  94%|███████████████████████████████████████████████████▋   | 47/50 [13:14<00:55, 18.55s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:46:48,131] Trial 47 finished with value: 0.9430332477723948 and parameters: {'iterations': 617, 'depth': 5, 'learning_rate': 0.2576101373543251, 'l2_leaf_reg': 0.0002609950171494826, 'random_strength': 2.6295691944863213, 'bagging_temperature': 3.630563231881669}. Best is trial 32 with value: 0.9492886914296292.
# Optimizing CatBoost Hyperparameters:  96%|████████████████████████████████████████████████████▊  | 48/50 [13:23<00:30, 15.48s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:46:59,343] Trial 48 finished with value: 0.9396727158254247 and parameters: {'iterations': 555, 'depth': 9, 'learning_rate': 0.16737319223223773, 'l2_leaf_reg': 0.25943824612716476, 'random_strength': 1.7538268261275942, 'bagging_temperature': 6.225093225006977}. Best is trial 32 with value: 0.9492886914296292.
# Optimizing CatBoost Hyperparameters:  98%|█████████████████████████████████████████████████████▉ | 49/50 [13:34<00:14, 14.20s/it]C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:6: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:7: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'l2_leaf_reg': trial.suggest_loguniform('l2_leaf_reg', 1e-5, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:8: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'random_strength': trial.suggest_uniform('random_strength', 1, 10),
# C:\Users\Brett Lill\AppData\Local\Temp\ipykernel_13864\3375288945.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'bagging_temperature': trial.suggest_uniform('bagging_temperature', 0, 10),
# [I 2024-10-17 15:47:07,092] Trial 49 finished with value: 0.944672156139274 and parameters: {'iterations': 961, 'depth': 6, 'learning_rate': 0.29487535995016717, 'l2_leaf_reg': 0.061618124612450656, 'random_strength': 5.70886112048858, 'bagging_temperature': 1.4472754529482126}. Best is trial 32 with value: 0.9492886914296292.
# Optimizing CatBoost Hyperparameters: 100%|███████████████████████████████████████████████████████| 50/50 [13:42<00:00, 16.44s/it]

# %%
# Train the CatBoost model with the best parameters
best_params = study.best_params
best_params.update({'random_state': 42, 'eval_metric': 'AUC', 'use_best_model': True})
model = CatBoostClassifier(**best_params)
model.fit(X_train_resampled, y_train_resampled, eval_set=[(X_validation, y_validation)], early_stopping_rounds=50, verbose=False)

# %%
# Make predictions on the validation set
y_pred = model.predict(X_validation)
y_pred_proba = model.predict_proba(X_validation)[:, 1]

# %%
# Evaluate the model
roc_auc = roc_auc_score(y_validation, y_pred_proba)
print(f"Optimized CatBoost - ROC AUC Score: {roc_auc}")
print(classification_report(y_validation, y_pred))
# Out:
# Optimized CatBoost - ROC AUC Score: 0.9492886914296292
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97     10087
#            1       0.84      0.72      0.77      1642
#
#     accuracy                           0.94     11729
#    macro avg       0.90      0.85      0.87     11729
# weighted avg       0.94      0.94      0.94     11729

# %% [markdown]
# ## Submission

# %%
# Load the test dataset

X_test = test_data
ids = pd.read_csv("../data/raw/test.csv")['id'].values

# Make predictions on the test set
y_test_pred_proba = model.predict_proba(X_test)[:, 1]

# Create a DataFrame for submission
submission = pd.DataFrame({'id': ids, 'loan_status': y_test_pred_proba})

# Save the submission to a CSV file
SUBMISSION_PATH = '../data/processed/submission.csv'
submission.to_csv(SUBMISSION_PATH, index=False)

print(f"Submission file saved to {SUBMISSION_PATH}")
# Out:
# Submission file saved to ../data/processed/submission.csv
